# %% [markdown]
# Este archivo brinda herramientas para identificar el ciclo economico actual mirando los indicadores planteados en el segundo capitulo (RCBC).

# %% [markdown]
# Inflacion interanual en Estados Unidos:

# %% [markdown]
# https://www.bls.gov/charts/consumer-price-index/consumer-price-index-by-category-line-chart.htm?

# %% [markdown]
# Para el crecimento se usan los datos extraidos de la OECD.
#  Output Gap estimado por OECD:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

df_oecd = pd.read_csv("Graficos/OECDevolucion.csv")

df_oecd["Date"] = pd.to_datetime(df_oecd["Date"], format="%Y")
df_oecd = df_oecd.sort_values("Date")

plt.figure(figsize=(12,5))
plt.plot(df_oecd["Date"], df_oecd["Value"], marker="o", linewidth=1)

ax = plt.gca()
ax.xaxis.set_major_locator(mdates.YearLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter("%Y"))
plt.xticks(rotation=45)

plt.title("Evolución del Output Gap OECD")
plt.xlabel("Fecha")
plt.ylabel("Value")
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()
